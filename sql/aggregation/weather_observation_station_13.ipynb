# %% [markdown]
# <a href="https://colab.research.google.com/github/carloslme/hackerrank/blob/main/sql/aggregation/weather_observation_station_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SOLUTION
# **Query**
# ```bash
# SELECT
#     ROUND(SUM(LAT_N), 4)
# FROM STATION
# WHERE LAT_N BETWEEN 38.7880 AND 137.2345;
# ```
