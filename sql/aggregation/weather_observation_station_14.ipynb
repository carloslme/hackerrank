# %% [markdown]
# <a href="https://colab.research.google.com/github/carloslme/hackerrank/blob/main/sql/aggregation/weather_observation_station_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SOLUTION
# **Query**
# ```bash
# SELECT
#     ROUND(MAX(LAT_N),4)
# FROM STATION
# WHERE LAT_N < 137.2345;
# ```
