# %% [markdown]
# <a href="https://colab.research.google.com/github/carloslme/hackerrank/blob/main/sql/aggregation/weather_observation_station_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SOLUTION
# **Query**
# ```bash
# SELECT
#     ROUND(LONG_W, 4)
# FROM STATION
# WHERE LAT_N > 38.7780
# ORDER BY LAT_N ASC
# LIMIT 1;
# ```
