# %% [markdown]
# <a href="https://colab.research.google.com/github/carloslme/hackerrank/blob/main/sql/basic_select/weather_observation_station_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution
# **Query**
#
# ```batch
# SELECT
#     DISTINCT(CITY)
# FROM STATION
# WHERE LEFT(LOWER(CITY), 1) IN ('a','e','i','o','u');
# ```
